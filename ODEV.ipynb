# %% [markdown]
# # Bilgisayar Mühendisliğine Giriş

# %% [markdown]
# ## ÖDEV

# %% [markdown]
# Balistik bir atışın güzergahlarını hesaplamak istiyoruz. Sabit başlangıç sürati ile fırlatılan bir cismin, farklı açılarla fırlatıldığında hareketini görselleyiniz.

# %% [markdown]
# Kütüphanelerimizi ekleyelim

# %%
import matplotlib.pylab as plt
import math as m

# %% [markdown]
# Başlangıç hızını v olarak tanımlayalım, ve yerçekimini tanımlayalım.

# %%
v = 30
g = 9.8

# %% [markdown]
# Denenecek farklı açıları bir listede oluşturun. 30 dereceden(m.pi/6), 5 derece araliklarla (m.pi/36) 10 tane  açı içeren  listeyi oluşturun.  Matematik kütüphanesinin pi fonksiyonunu kullanabilirsiniz. m.pi

# %%
theta = []

# %%
theta
# Out:
# [0.5235987755982988,
#  0.6108652381980153,
#  0.6981317007977318,
#  0.7853981633974483,
#  0.8726646259971647,
#  0.9599310885968813,
#  1.0471975511965976,
#  1.1344640137963142,
#  1.2217304763960306,
#  1.308996938995747]

# %% [markdown]
# Simülasyonumuza başlamadan önce bir zaman aralığı ve adım boyutu belirleyin. 5 saniye uygun bir başlangıç olabilir, ve bir zaman vektörü oluşturun.

# %%
t = []
adim = 0.05

# %%
t
# Out:
# [0.0,
#  0.05,
#  0.1,
#  0.15000000000000002,
#  0.2,
#  0.25,
#  0.30000000000000004,
#  0.35000000000000003,
#  0.4,
#  0.45,
#  0.5,
#  0.55,
#  0.6000000000000001,
#  0.65,
#  0.7000000000000001,
#  0.75,
#  0.8,
#  0.8500000000000001,
#  0.9,
#  0.9500000000000001,
#  1.0,
#  1.05,
#  1.1,
#  1.1500000000000001,
#  1.2000000000000002,
#  1.25,
#  1.3,
#  1.35,
#  1.4000000000000001,
#  1.4500000000000002,
#  1.5,
#  1.55,
#  1.6,
#  1.6500000000000001,
#  1.7000000000000002,
#  1.75,
#  1.8,
#  1.85,
#  1.9000000000000001,
#  1.9500000000000002,
#  2.0,
#  2.0500000000000003,
#  2.1,
#  2.15,
#  2.2,
#  2.25,
#  2.3000000000000003,
#  2.35,
#  2.4000000000000004,
#  2.45,
#  2.5,
#  2.5500000000000003,
#  2.6,
#  2.6500000000000004,
#  2.7,
#  2.75,
#  2.8000000000000003,
#  2.85,
#  2.9000000000000004,
#  2.95,
#  3.0,
#  3.0500000000000003,
#  3.1,
#  3.1500000000000004,
#  3.2,
#  3.25,
#  3.3000000000000003,
#  3.35,
#  3.4000000000000004,
#  3.45,
#  3.5,
# ...

# %% [markdown]
# Simülasyon parametrelerinimz hazır olduğuna göre, balistik atış formülünü bir fonksiyona çevirin. Fonksiyonunuz açıyı, zamanı, başlangıç süratini ve yerçekimini almalı. Ve yatay ve dikey eksendeki konumu geri dönüdürmeli (x,y)

# %% [markdown]
# $$
# x = v_0t = v_0 cos(\theta)t
# $$
#
# $$
# y = v_0t - 1/2gt^2 = v_0 sin(\theta)t-1/2gt^2
# $$

# %%
def konum(aci, zaman, v, g):

    

    return x,y

# %% [markdown]
# Simdi belirlediğimiz simülasyon parametreleri ile, simülasyonumuzu koşturabiliriz. Belirlediğimiz her açı için, her bir zaman noktası için sonuçları bir grafik üzerinde görselletiniz. Yukarıda oluşturduğunuz, zamanları içeren t vektörünü değiştirmeniz gerekcektir. (her bir atışın, y ekseninde 0'a, yani yere ulaştığını görmeniz lazım).

# %%
fig, ax = plt.subplots()

for aci in theta: # her bir aci icin
    # bu aci icin olusturulacak listeleri sifirla


    # zaman vektorundeki her bir zaman icin

        #koordinatlari hesapla


        #listeye ekle

                         
    #grafige ekleme
                        # her bir atisin grafigini ekle

plt.show() # Bir gorselde goster

# %% [markdown]
# Oluşturduğunuz görselin başlığını, eksen isimlerini ve lejandını düzenleyiniz.

# %% [markdown]
# Görselinizi yorumlayarak hangi açı ile yapılan atışın en uzağa gittiğini söyleyiniz.

# %% [markdown]
# BONUS: Görselinizin verisini oluştrurken, 0'ın altındaki değerleri silin. (Cismin yerin altındaki hareketini göstermeyin)
