# %% [markdown]
# # Veri Görselleme 3
#
# Verilerimizi csv ve benzeri dosyalardan okumak ve analizler yapmak için Pandas kütüphanesi günümüzde öne çıkan açık kaynak kodlu ve ücrestiz kütüphanelerden biridir.
#
# Adı panel data kelimelerinin birleşiminden türetilmiştir.
#
# Hızlı çalışır
# Farklı dosyalardan hafızaya veri yükleme olanağı sağlar
# Eksik verilerle de çalışma imkanı sunar
# Veri setlerini yeniden şekillendirmeye olanak tanır
# Etiketlerden yola çıkarak veriyi farklı indekslere ve bölümlere bölebilir
# Sütunlar eklenip silinebilir
# Zamansal verilerle de çalışır

# %% [markdown]
# 3 Temel veri yapısı vardır
# 'Seriler' Aynı türde veri içeren, değerleri değiştirilebilen liseteler.
# 'Data Frame' 2 boyutlu listeler
# 'Panel' 3 boyutlu listeler

# %%
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = [1,2,3,4,5]
df = pd.DataFrame(data)
print (df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data = [['Ahmet',10],['Mehmet',12],['Ayse',13]]
df = pd.DataFrame(data,columns=['Isim','Yas'])
print(df)
# Out:
#      Isim  Yas
# 0   Ahmet   10
# 1  Mehmet   12
# 2    Ayse   13

# %%
data = {'Isim':['Ali', 'Ahmet', 'Mehmet','Ayse'],'Yas':[28,34,29,42]}
df = pd.DataFrame(data)
print(df)
# Out:
#      Isim  Yas
# 0     Ali   28
# 1   Ahmet   34
# 2  Mehmet   29
# 3    Ayse   42

# %%
print(df['Yas'])
# Out:
# 0    28
# 1    34
# 2    29
# 3    42
# Name: Yas, dtype: int64

# %%
df['Meslek'] = pd.Series(['Muhendis', 'Ogretmen','Bakkal','Analist'])
print(df)
# Out:
#      Isim  Yas    Meslek
# 0     Ali   28  Muhendis
# 1   Ahmet   34  Ogretmen
# 2  Mehmet   29    Bakkal
# 3    Ayse   42   Analist

# %%
print(df[1:3])
# Out:
#      Isim  Yas    Meslek
# 1   Ahmet   34  Ogretmen
# 2  Mehmet   29    Bakkal

# %%
print(df.head())
print("\n")
print(df.head(2))
# Out:
#      Isim  Yas    Meslek
# 0     Ali   28  Muhendis
# 1   Ahmet   34  Ogretmen
# 2  Mehmet   29    Bakkal
# 3    Ayse   42   Analist
#
#
#     Isim  Yas    Meslek
# 0    Ali   28  Muhendis
# 1  Ahmet   34  Ogretmen

# %%
print(df.tail())
print("\n")
print(df.tail(2))
# Out:
#      Isim  Yas    Meslek
# 0     Ali   28  Muhendis
# 1   Ahmet   34  Ogretmen
# 2  Mehmet   29    Bakkal
# 3    Ayse   42   Analist
#
#
#      Isim  Yas   Meslek
# 2  Mehmet   29   Bakkal
# 3    Ayse   42  Analist

# %%
print("Dimension of df:>>>", df.ndim, "<<<")
# Out:
# Dimension of df:>>> 2 <<<

# %%
print("Shape of df:>>>", df.shape, "<<<")
# Out:
# Shape of df:>>> (4, 3) <<<

# %%
# Satir sayisi
df.shape[0]
# Out:
# 4

# %%
# Sutun Sayisi
df.shape[1]
# Out:
# 3

# %% [markdown]
# Pandas ile dokuman okumak kolay.

# %%
pd.read_csv('ev.csv', delimiter = ',')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      220         120       RL         43.0     3010   Pave   NaN      Reg
# 1      230         120       RL         43.0     3182   Pave   NaN      Reg
# 2      386         120       RL         43.0     3182   Pave   NaN      Reg
# 3      444         120       RL         53.0     3922   Pave   NaN      Reg
# 4      466         120       RM          NaN     3072   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455   765         120       RL         30.0     9549   Pave   NaN      IR1
# 1456   850          80       RL         80.0     9600   Pave   NaN      Reg
# 1457  1156          20       RL         90.0    10768   Pave   NaN      IR1
# 1458  1165          80       RL          NaN    16157   Pave   NaN      IR1
# 1459  1254          60       RL          NaN    17542   Pave   NaN      IR1
#
# ...

# %%
df = pd.read_csv('ev.csv', delimiter = ',')

# %%
df.head(5)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  NeighborhoodID Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# ...

# %%
df.tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455   765         120       RL         30.0     9549   Pave   NaN      IR1
# 1456   850          80       RL         80.0     9600   Pave   NaN      Reg
# 1457  1156          20       RL         90.0    10768   Pave   NaN      IR1
# 1458  1165          80       RL          NaN    16157   Pave   NaN      IR1
# 1459  1254          60       RL          NaN    17542   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence  MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN          NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN          NaN       0
# 1457         Lvl    AllPub  ...        0    NaN    NaN          NaN       0
# 1458         Lvl    AllPub  ...        0    NaN    NaN          NaN       0
# 1459         Lvl    AllPub  ...        0    NaN  MnPrv          NaN       0
#
# ...

# %%
df['LotArea']
# Out:
# 0        3010
# 1        3182
# 2        3182
# 3        3922
# 4        3072
#         ...
# 1455     9549
# 1456     9600
# 1457    10768
# 1458    16157
# 1459    17542
# Name: LotArea, Length: 1460, dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'NeighborhoodID', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  NeighborhoodID  OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold       YrSold      SalePrice
# ...

# %% [markdown]
# aradaki degerleri gostermiyor ...
# pandas a bir ayar yapalım

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df[['LotArea','SalePrice']]
# Out:
#       LotArea  SalePrice
# 0        3010     167240
# 1        3182     192500
# 2        3182     192000
# 3        3922     172500
# 4        3072     178740
# ...       ...        ...
# 1455     9549     270000
# 1456     9600     187000
# 1457    10768     218000
# 1458    16157     194000
# 1459    17542     294000
#
# [1460 rows x 2 columns]

# %%
df['Neighborhood']
# Out:
# 0       Blmngtn
# 1       Blmngtn
# 2       Blmngtn
# 3       Blmngtn
# 4       Blmngtn
#          ...
# 1455    Veenker
# 1456    Veenker
# 1457    Veenker
# 1458    Veenker
# 1459    Veenker
# Name: Neighborhood, Length: 1460, dtype: object

# %%
df[['Neighborhood','SalePrice','LotArea']].count()
# Out:
# Neighborhood    1460
# SalePrice       1460
# LotArea         1460
# dtype: int64

# %%
df['SalePrice'].mean()
# Out:
# 180921.19589041095

# %%
df['SalePrice'].median()
# Out:
# 163000.0

# %%
evler = pd.DataFrame(df[['Neighborhood','SalePrice','LotArea','NeighborhoodID']])
print(evler)
# Out:
#      Neighborhood  SalePrice  LotArea  NeighborhoodID
# 0         Blmngtn     167240     3010               1
# 1         Blmngtn     192500     3182               1
# 2         Blmngtn     192000     3182               1
# 3         Blmngtn     172500     3922               1
# 4         Blmngtn     178740     3072               1
# ...           ...        ...      ...             ...
# 1455      Veenker     270000     9549              25
# 1456      Veenker     187000     9600              25
# 1457      Veenker     218000    10768              25
# 1458      Veenker     194000    16157              25
# 1459      Veenker     294000    17542              25
#
# [1460 rows x 4 columns]

# %%
evler.groupby('Neighborhood').mean()
# Out:
#                   SalePrice       LotArea  NeighborhoodID
# Neighborhood
# Blmngtn       194870.882353   3398.176471             1.0
# Blueste       137500.000000   1625.000000             2.0
# BrDale        104493.750000   1801.000000             3.0
# BrkSide       124834.051724   7360.413793             4.0
# ClearCr       212565.428571  30875.750000             5.0
# CollgCr       197965.773333   9619.146667             6.0
# Crawfor       210624.725490  11809.686275             7.0
# Edwards       128219.700000  10218.650000             8.0
# Gilbert       192854.506329  11379.151899             9.0
# IDOTRR        100123.783784   8109.162162            10.0
# MeadowV        98576.470588   2324.000000            11.0
# Mitchel       156270.122449  11624.285714            12.0
# NAmes         145847.080000  10139.915556            13.0
# NPkVill       142694.444444   3267.444444            15.0
# NWAmes        189050.068493  11833.630137            17.0
# ...

# %%
evler.groupby('Neighborhood').mean().sort_values('SalePrice')
# Out:
#                   SalePrice       LotArea  NeighborhoodID
# Neighborhood
# MeadowV        98576.470588   2324.000000            11.0
# IDOTRR        100123.783784   8109.162162            10.0
# BrDale        104493.750000   1801.000000             3.0
# BrkSide       124834.051724   7360.413793             4.0
# Edwards       128219.700000  10218.650000             8.0
# OldTown       128225.300885   8207.061947            18.0
# Sawyer        136793.135135  10459.283784            19.0
# Blueste       137500.000000   1625.000000             2.0
# SWISU         142591.360000   8127.560000            23.0
# NPkVill       142694.444444   3267.444444            15.0
# NAmes         145847.080000  10139.915556            13.0
# Mitchel       156270.122449  11624.285714            12.0
# SawyerW       186555.796610   9923.796610            20.0
# NWAmes        189050.068493  11833.630137            17.0
# Gilbert       192854.506329  11379.151899             9.0
# ...

# %%
evler.groupby('Neighborhood').mean().sort_values('LotArea')
# Out:
#                   SalePrice       LotArea  NeighborhoodID
# Neighborhood
# Blueste       137500.000000   1625.000000             2.0
# BrDale        104493.750000   1801.000000             3.0
# MeadowV        98576.470588   2324.000000            11.0
# NPkVill       142694.444444   3267.444444            15.0
# Blmngtn       194870.882353   3398.176471             1.0
# BrkSide       124834.051724   7360.413793             4.0
# Somerst       225379.837209   7840.872093            21.0
# IDOTRR        100123.783784   8109.162162            10.0
# SWISU         142591.360000   8127.560000            23.0
# OldTown       128225.300885   8207.061947            18.0
# CollgCr       197965.773333   9619.146667             6.0
# SawyerW       186555.796610   9923.796610            20.0
# NAmes         145847.080000  10139.915556            13.0
# Edwards       128219.700000  10218.650000             8.0
# Sawyer        136793.135135  10459.283784            19.0
# ...

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# Verilerimize bakarak metre kareye göre fiyat tahmini yapmamız mümkün olur mu?

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 15]

fig, ax = plt.subplots()

ax.scatter(evler['LotArea'], evler['SalePrice'], alpha =0.2)


ax.set(xlabel='alan', ylabel='fiyat',
       title='fiyat/alan oranı')

plt.show()

# %% [markdown]
# Bu grafikleri pandas ile üretmek de mümkün.

# %%
ax2 = evler.plot.scatter(x='LotArea',y='SalePrice')
plt.show()

# %%
ax2 = evler.plot.scatter(x='LotArea', y='SalePrice', c='NeighborhoodID', s = 500, colormap='viridis')
plt.show()

# %% [markdown]
# Yukarıdaki görselimizi daha iyi anlayabilmek için belki parametreleri ne nokta boyutunu büyütmek için birşeyler ekleyebiliriz.
# s=500

# %% [markdown]
# Notkaların şeffaflığını değiştirirsek, altta kalan veriyi de göreblime ihtimalimiz var.
# alpha=0.2

# %%
evler2 = evler[evler.NeighborhoodID ==5]
ax2 = evler2.plot.scatter(x='LotArea', y='SalePrice', c='NeighborhoodID',s=200,colormap='viridis')
plt.show()

# %% [markdown]
# Daha farklı şekilde görseller oluşturmak için aşağıdaki linke tıklayın:
#     https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots

# %% [markdown]
# Verilerimizi inceleyelerek gözle görülür bir bilgi çıkaramadık. Belki yeterince bilgiyi göremiyoruz.

# %% [markdown]
# Veri setimizde evin genel kalitesi ve evin durumu hakkında bilgiler de mevcut bunları kullanmaya çalışalım.

# %% [markdown]
# Kalite: IKEA - Dolmabahçe Sarayı el işçiliği

# %% [markdown]
# Durum:  Dökülüyor - Yeni

# %%
df['OverallCond'].describe()
# Out:
# count    1460.000000
# mean        5.575342
# std         1.112799
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: OverallCond, dtype: float64

# %%
df['OverallQual'].describe()
# Out:
# count    1460.000000
# mean        6.099315
# std         1.382997
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64

# %%
evler3 = pd.DataFrame(df[['Neighborhood','SalePrice','LotArea','NeighborhoodID','TotRmsAbvGrd','OverallQual','OverallCond']])
evler3.head()
evler3.describe()

#evler3 = evler3[evler.NeighborhoodID ==13]



size = 100*evler3['TotRmsAbvGrd']
#size = 100*evler3['OverallQual']

# %%
ax3 = evler3[evler3.NeighborhoodID ==11].plot.scatter(x='LotArea', y='SalePrice', c='OverallCond', s=size ,alpha=0.5,colormap='inferno')
plt.show()

# %% [markdown]
# Teker Teker zor oluyor. Bir döngüye alalım da hepsini göstersin bize

# %%
plt.rcParams['figure.figsize'] = [10, 10]
for e in range(1,evler3.NeighborhoodID.max()+1):
    ax3 = evler3[evler3.NeighborhoodID ==e].plot.scatter(x='LotArea', y='SalePrice', c='OverallCond', s=size,alpha=0.5,colormap='viridis')
    ax3.legend(str(e))
    
    plt.show()

# %% [markdown]
# Bu da olmadi sanki. Ah bir de oda asıyısını aynı çizimde görebilsem kesin malum olur bana...   :)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


#evler3 = evler3[evler3.NeighborhoodID ==22]

ax.scatter(evler3['LotArea'], evler3['TotRmsAbvGrd'],evler3['SalePrice'],  c=evler3['OverallCond'],s=10*evler3['OverallQual'], marker='^')
#ax.scatter(xt, yt, zt, c='b',s=10, marker='^')

ax.set_xlabel('Alan')
ax.set_ylabel('Oda Sayisi')
ax.set_zlabel('Fiyat')

plt.show()

# %% [markdown]
# https://matplotlib.org/3.1.1/api/markers_api.html
